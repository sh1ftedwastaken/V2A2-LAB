# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/limo_unet_implementation.zip -d /content/limo_unet_implementation
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/limo_unet_implementation/frames_with_extra_cars_post_deletions/counterclockwise/4/frame_000033_20260303_062537_529129.json
#   inflating: /content/limo_unet_implementation/frames_with_extra_cars_post_deletions/counterclockwise/4/frame_000033_20260303_062537_529129.png
#   inflating: /content/limo_unet_implementation/frames_with_extra_cars_post_deletions/counterclockwise/4/frame_000034_20260303_062538_528984.jpg
#   inflating: /content/limo_unet_implementation/frames_with_extra_cars_post_deletions/counterclockwise/4/frame_000034_20260303_062538_528984.json
#   inflating: /content/limo_unet_implementation/frames_with_extra_cars_post_deletions/counterclockwise/4/frame_000034_20260303_062538_528984.png
#   inflating: /content/limo_unet_implementation/frames_with_extra_cars_post_deletions/counterclockwise/4/frame_000035_20260303_062539_531073.jpg
# ...

# %%
# !pip install torch torchvision pillow numpy

# %%
# !python /content/limo_unet_implementation/frames_with_extra_cars_post_deletions/unet_code/train.py \
  --images_dir /content/limo_unet_implementation/frames_with_extra_cars_post_deletions/data/images \
  --masks_dir /content/limo_unet_implementation/frames_with_extra_cars_post_deletions/data/masks \
  --loss combo \
  --epochs 50 \
  --batch_size 8 \
  --workers 2 \
  --output_dir /content/drive/MyDrive/checkpoints/combo
# Out:
# [device]  cuda
# [data]    train=641  val=112
# [model]   LightUNet  params=825,653
# [loss]    combo
# /content/limo_unet_implementation/frames_with_extra_cars_post_deletions/unet_code/train.py:362: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler  = torch.cuda.amp.GradScaler() if use_amp else None
# [amp]     mixed precision ON
#
#   Ep     Train       Val    mIoU     bg  lane   yel   wht   obs      t
# ---------------------------------------------------------------------------
#    1    0.4329    0.1056  0.8473  0.993 0.966 0.585 0.767 0.926   8.0s
#        Best saved  mIoU=0.8473  -> /content/drive/MyDrive/checkpoints/combo/best.pth
#    2    0.0603    0.0550  0.8853  0.995 0.971 0.595 0.907 0.958   5.5s
#        Best saved  mIoU=0.8853  -> /content/drive/MyDrive/checkpoints/combo/best.pth
#    3    0.0526    0.0490  0.8931  0.995 0.973 0.615 0.916 0.967   6.0s
# ...

# %%
# %cd /content/limo_unet_implementation/frames_with_extra_cars_post_deletions/unet_code
# Out:
# /content/limo_unet_implementation/frames_with_extra_cars_post_deletions/unet_code

# %%
# !python train.py \
  --images_dir ../data/images \
  --masks_dir ../data/masks \
  --loss dice \
  --lr 3e-4 \
  --epochs 50 \
  --batch_size 8 \
  --workers 2 \
  --output_dir /content/drive/MyDrive/checkpoints/dice
# Out:
# [device]  cuda
# [data]    train=641  val=112
# [model]   LightUNet  params=825,653
# [loss]    dice
# /content/limo_unet_implementation/frames_with_extra_cars_post_deletions/unet_code/train.py:362: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler  = torch.cuda.amp.GradScaler() if use_amp else None
# [amp]     mixed precision ON
#
#   Ep     Train       Val    mIoU     bg  lane   yel   wht   obs      t
# ---------------------------------------------------------------------------
#    1    0.7227    0.4530  0.4277  0.781 0.214 0.256 0.036 0.851   6.9s
#        Best saved  mIoU=0.4277  -> /content/drive/MyDrive/checkpoints/dice/best.pth
#    2    0.2192    0.0877  0.8650  0.994 0.966 0.602 0.805 0.958   6.0s
#        Best saved  mIoU=0.8650  -> /content/drive/MyDrive/checkpoints/dice/best.pth
#    3    0.0868    0.0759  0.8817  0.994 0.967 0.611 0.869 0.967   6.0s
# ...

# %%
# !python train.py \
  --images_dir ../data/images \
  --masks_dir ../data/masks \
  --loss focal \
  --gamma 2.0 \
  --epochs 50 \
  --batch_size 8 \
  --workers 2 \
  --output_dir /content/drive/MyDrive/checkpoints/focal
# Out:
# [device]  cuda
# [data]    train=641  val=112
# [model]   LightUNet  params=825,653
# [loss]    focal  gamma=2.0
# /content/limo_unet_implementation/frames_with_extra_cars_post_deletions/unet_code/train.py:362: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler  = torch.cuda.amp.GradScaler() if use_amp else None
# [amp]     mixed precision ON
#
#   Ep     Train       Val    mIoU     bg  lane   yel   wht   obs      t
# ---------------------------------------------------------------------------
#    1    0.2308    0.0259  0.6571  0.994 0.932 0.046 0.387 0.926   6.7s
#        Best saved  mIoU=0.6571  -> /content/drive/MyDrive/checkpoints/focal/best.pth
#    2    0.0152    0.0104  0.8721  0.995 0.974 0.570 0.875 0.946   5.9s
#        Best saved  mIoU=0.8721  -> /content/drive/MyDrive/checkpoints/focal/best.pth
#    3    0.0087    0.0080  0.8785  0.995 0.975 0.594 0.867 0.961   5.9s
# ...

# %%
# !zip -r dice_results.zip /content/drive/MyDrive/checkpoints/dice
# Out:
#   adding: content/drive/MyDrive/checkpoints/dice/ (stored 0%)
#   adding: content/drive/MyDrive/checkpoints/dice/best.pth (deflated 7%)
#   adding: content/drive/MyDrive/checkpoints/dice/last.pth (deflated 8%)

# %%
from google.colab import files
files.download('dice_results.zip')

# %%
# !zip -r all_results.zip /content/drive/MyDrive/checkpoints
# Out:
#   adding: content/drive/MyDrive/checkpoints/ (stored 0%)
#   adding: content/drive/MyDrive/checkpoints/combo/ (stored 0%)
#   adding: content/drive/MyDrive/checkpoints/combo/best.pth (deflated 11%)
#   adding: content/drive/MyDrive/checkpoints/combo/last.pth (deflated 8%)
#   adding: content/drive/MyDrive/checkpoints/dice/ (stored 0%)
#   adding: content/drive/MyDrive/checkpoints/dice/best.pth (deflated 7%)
#   adding: content/drive/MyDrive/checkpoints/dice/last.pth (deflated 8%)
#   adding: content/drive/MyDrive/checkpoints/focal/ (stored 0%)
#   adding: content/drive/MyDrive/checkpoints/focal/best.pth (deflated 14%)
#   adding: content/drive/MyDrive/checkpoints/focal/last.pth (deflated 8%)

# %%
from google.colab import files
files.download('all_results.zip')
